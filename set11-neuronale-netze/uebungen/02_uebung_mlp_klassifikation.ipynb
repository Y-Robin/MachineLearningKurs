# %% [markdown]
# # Übung 2 – Binäre MLP-Klassifikation
#
# ## Ziel
#
# Trainiere auf dem Breast-Cancer-Lehrdatensatz von scikit-learn eine binäre Klassifikation. Anders als im Beispiel mit drei Softmax-Ausgängen verwendet `MLPClassifier` hier einen logistischen Output.
#
# > Der Datensatz dient ausschließlich als technische ML-Übung und nicht als medizinisches Diagnosewerkzeug.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, ConfusionMatrixDisplay, RocCurveDisplay, make_scorer
RANDOM_STATE = 42

# %% [markdown]
# ## Aufgabe 1 – Daten und Zielklassen
#
# Lade den Datensatz mit `as_frame=True`. Prüfe Form, fehlende Werte und Klassenhäufigkeiten. Erkläre, warum ein stratifizierter Split sinnvoll ist, und reserviere 25 % als Testdaten.

# %%
# TODO: Daten laden, untersuchen und stratifiziert aufteilen

# %% [markdown]
# ## Aufgabe 2 – Binäres MLP
#
# Erstelle eine skalierte Pipeline mit `(32, 16)`, ReLU, Adam, Early Stopping und L2-Regularisierung. Berichte Accuracy, Precision, Recall und F1. Prüfe `n_outputs_` und `out_activation_`.
#
# Erkläre, weshalb scikit-learn für zwei Klassen ein logistisches Output-Neuron und Log-Loss verwendet und wie `predict_proba` daraus zwei Spalten erzeugt.

# %%
# TODO: Modell trainieren, Wahrscheinlichkeiten und Output untersuchen

# %% [markdown]
# ## Aufgabe 3 – Hyperparameter optimieren
#
# Optimiere kleine Strukturen, Hidden-Aktivierung, Lernrate und `alpha` mit 3-Fold-Cross-Validation. Im Datensatz ist die maligne Klasse als `0` kodiert. Erzeuge deshalb mit `make_scorer(recall_score, pos_label=0)` einen Score, der gezielt den Recall der malignen Klasse optimiert. Begründe, warum ein gewöhnliches `scoring="recall"` hier die falsche Klasse bewerten würde.

# %%
# TODO: GridSearchCV mit begründetem Scoring

# %% [markdown]
# ## Aufgabe 4 – Finale Bewertung
#
# Zeige Classification Report, Konfusionsmatrix, ROC-Kurve und Loss-Kurve. Vergleiche CV- und Testscore. Beschreibe außerdem, welchen Einfluss eine höhere Lernrate, ein größeres `alpha` und ein größeres Netz jeweils haben können.

# %%
# TODO: finales Modell bewerten und Ergebnisse interpretieren
