# %% [markdown]
# # Übung 1 – MLP-Regression mit dem Diabetes-Datensatz
#
# ## Ziel
#
# Trainiere ein neuronales Netz für ein Regressionsproblem mit zehn Eingabemerkmalen und genau einem kontinuierlichen Output. Nutze einen anderen Datensatz als im Beispiel und optimiere nur einige kleine Architekturen.
#
# > Der Datensatz dient ausschließlich als technische ML-Übung und nicht als medizinisches Diagnosewerkzeug.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
RANDOM_STATE = 42


# Der Datensatz wird für die Übung direkt bereitgestellt.
# X enthält die zehn numerischen Eingabemerkmale, y den kontinuierlichen Zielwert.
diabetes = load_diabetes(as_frame=True)
X = diabetes.data.copy()
y = diabetes.target.copy()

print("Datensatz erfolgreich geladen.")
print("X:", X.shape, "y:", y.shape)

# %% [markdown]
# ## Aufgabe 1 – Die bereitgestellten Daten verstehen
#
# Die Variablen `X` und `y` sind bereits vorhanden. Untersuche nun den Datensatz:
#
# 1. Zeige die ersten Zeilen von `X`.
# 2. Prüfe fehlende Werte und Datentypen.
# 3. Berechne eine deskriptive Statistik der Eingabemerkmale.
# 4. Visualisiere die Verteilung der Zielvariable `y`.
# 5. Teile anschließend 25 % der Beobachtungen als Testdaten ab. Verwende `random_state=42`.

# %%
# TODO: Die bereits geladenen Variablen X und y untersuchen und aufteilen

# %% [markdown]
# ## Aufgabe 2 – Erstes neuronales Netz
#
# Erstelle eine Pipeline aus `StandardScaler` und `MLPRegressor`. Verwende zunächst `(32, 16)`, ReLU, Adam, eine Lernrate von `0.001`, `alpha=0.001`, Early Stopping und einen festen `random_state`. Trainiere das Modell und berichte MAE, RMSE sowie $R^2$.
#
# Gib außerdem `n_outputs_`, `out_activation_`, `n_iter_` und die Formen aller Gewichtsmatrizen aus. Erkläre, warum genau ein Output-Neuron benötigt wird.

# %%
# TODO: erste Pipeline trainieren und untersuchen

# %% [markdown]
# ## Aufgabe 3 – Kleine Hyperparametersuche
#
# Optimiere per 3-Fold-`GridSearchCV` mindestens:
#
# - `hidden_layer_sizes`: `(16,)`, `(32,)`, `(32, 16)`
# - `activation`: `relu`, `tanh`
# - `learning_rate_init`: `0.001`, `0.01`
# - `alpha`: `0.0001`, `0.01`
#
# Verwende `neg_root_mean_squared_error`. Zeige die acht besten Kombinationen und erläutere die Bedeutung des negativen Scores.

# %%
# TODO: GridSearchCV durchführen

# %% [markdown]
# ## Aufgabe 4 – Finale Auswertung
#
# Bewerte `best_estimator_` genau einmal auf dem Testdatensatz. Zeichne tatsächliche gegen vorhergesagte Werte sowie die Loss-Kurve des finalen Netzes. Vergleiche CV-RMSE und Test-RMSE. Welche Hinweise auf Underfitting oder Overfitting erkennst du?

# %%
# TODO: finales Modell auswerten und visualisieren
