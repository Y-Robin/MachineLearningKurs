# %% [markdown]
# # Übung 1 – SVM-Klassifikation mit Wine
#
# Trainiere auf `load_wine` eine SVM für drei Klassen. Nutze 25 % Testdaten, `stratify=y`, `random_state=42`, eine Pipeline und `f1_macro`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, classification_report, ConfusionMatrixDisplay
RANDOM_STATE=42

# %% [markdown]
# ## Aufgabe 1 – Daten
#
# Lade mit `as_frame=True`. Zeige Form, Kopf, fehlende Werte und Klassenhäufigkeiten. Zeichne nach Klasse getrennte Histogramme für `alcohol`, `color_intensity`, `proline`.

# %%
# TODO: Datenanalyse

# %% [markdown]
# ## Aufgabe 2 – Baseline
#
# Erstelle den Split. Trainiere `StandardScaler` + lineare `SVC`. Berichte Accuracy und Macro-F1. Warum steht der Scaler in der Pipeline?

# %%
# TODO: Baseline

# %% [markdown]
# ## Aufgabe 3 – Suche
#
# 5-Fold-GridSearch mit `f1_macro`: linear mit `C=[.01,.1,1,10]`; poly mit `C=[.1,1,10]`, `gamma=['scale',.01,.1]`, `degree=[2,3]`; RBF mit `C=[.1,1,10,100]`, `gamma=[.001,.01,.1,1]`. Zeige die besten zehn.

# %%
# TODO: GridSearchCV

# %% [markdown]
# ## Aufgabe 4 – Test
#
# Zeige Report, Konfusionsmatrix, `n_support_`, Gesamtzahl der Support-Vektoren und CV-vs-Test-F1. Zusatz: beste SVC ohne Skalierung.

# %%
# TODO: finale Bewertung
