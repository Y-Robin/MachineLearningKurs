# %% [markdown]
# # Übung 2 – SVR mit Diabetes
#
# Optimiere eine SVR auf `load_diabetes`. Nutze 25 % Testdaten, CV-RMSE und berichte MAE, RMSE, $R^2$. Dies ist eine technische Übung, keine medizinische Empfehlung.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
RANDOM_STATE=42

# %% [markdown]
# ## Aufgabe 1 – Daten
#
# Zeige Form, Statistik, fehlende Werte und Zielverteilung. Ermittle fünf Merkmale mit stärkster absoluter Zielkorrelation. Warum ist Korrelation keine Kausalität?

# %%
# TODO: Datenanalyse

# %% [markdown]
# ## Aufgabe 2 – Baselines
#
# Nutze Trainingsziel-Mittelwert als Dummy. Vergleiche skalierte SVRs mit linear, poly, RBF anhand MAE, RMSE, R² und Support-Anzahl.

# %%
# TODO: Modelle vergleichen

# %% [markdown]
# ## Aufgabe 3 – Suche
#
# 5-Fold-GridSearch: linear mit C/epsilon; poly mit C/gamma/degree/epsilon; RBF mit C/gamma/epsilon. Nutze `neg_root_mean_squared_error`, erkläre das Minus und zeige die Top 10.

# %%
# TODO: GridSearchCV

# %% [markdown]
# ## Aufgabe 4 – Test und epsilon
#
# Bewerte das beste Modell, zeichne Ist vs. Prognose, gib Support-Anteil aus. Variiere nur `epsilon` und vergleiche RMSE sowie Support-Anzahl.

# %%
# TODO: finale Bewertung
