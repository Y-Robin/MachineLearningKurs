# %% [markdown]
# # Übung 3 – Fragen zu SVM und SVR
#
# 1. Hyperebene in 2D/3D? 2. Was ist Margin? 3. Warum maximale Margin? 4. Was sind Support-Vektoren? 5. Wirkung eines weit entfernten Punkts? 6. Hard vs. Soft Margin? 7. Slack-Variablen? 8. Hinge Loss?
#
# 9. Warum skalieren? 10. Kleines/großes `C`? 11. Ist großes `C` immer besser? 12. Bedeutung von `gamma`? 13. Risiko bei großem C und gamma? 14. Warum gamma nicht bei linear? 15. `gamma='scale'`? 16. Warum Scaler in Pipeline/CV?
#
# 17. Kernel-Trick? 18. Wann linear? 19. Poly-Parameter? 20. Linear vs. poly vs. RBF? 21. Mehrklassen-SVC? 22. OVR vs. OVO?
#
# 23. epsilon-Tunnel? 24. Fehler darin? 25. Größeres epsilon: Support und Genauigkeit? 26. C vs. epsilon? 27. Warum keine Accuracy für Regression? 28. MAE vs. RMSE?
#
# 29. Warum Testdaten nicht zum Tuning? 30. Zweck CV? 31. Warum negativer RMSE? 32. Training-F1 1,00, CV .72, Test .69: Diagnose? 33. RBF sagt eine Klasse: Parameterursachen? 34. Größeres epsilon, weniger Support, höherer RMSE? 35. Zwei Vor-/Nachteile? 36. Problem bei riesigen Daten? 37. Dünne Textdaten: Kernel? 38. Kreisgrenze: Kernel? 39. Seltene Klasse: Metrik/Parameter? 40. Sauberer Workflow?
