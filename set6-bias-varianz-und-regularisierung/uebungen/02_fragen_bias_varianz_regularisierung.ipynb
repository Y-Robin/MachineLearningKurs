# %% [markdown]
# # Fragen – Bias, Varianz und Regularisierung

# %% [markdown]
# ## Generalisierung und Modellkomplexität
#
# 1. Warum reicht ein kleiner Trainingsfehler nicht aus?
# 2. Was unterscheidet Trainings-, Validierungs- und Testdaten?
# 3. Woran erkennt man Underfitting?
# 4. Woran erkennt man Overfitting?
# 5. Was bedeutet hoher Bias?
# 6. Was bedeutet hohe Varianz?
# 7. Wie verändert ein höherer Polynomgrad die Modellkomplexität?
# 8. Warum steigt der Validierungsfehler bei sehr hoher Komplexität häufig wieder?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## Cross-Validation und Modellwahl
#
# 9. Warum ist Cross-Validation stabiler als ein einzelner Validierungssplit?
# 10. Was ist ein Hyperparameter?
# 11. Warum darf der Testsatz nicht zur Wahl von Grad oder alpha verwendet werden?
# 12. Was macht GridSearchCV?
# 13. Warum sollten bei ähnlicher Leistung einfachere Modelle bevorzugt werden?
# 14. Was ist Data Leakage bei der Skalierung?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## Regularisierung
#
# 15. Was ergänzt Regularisierung zur ursprünglichen Loss-Funktion?
# 16. Wie wirkt ein kleines und wie ein großes alpha?
# 17. Was ist der Unterschied zwischen Ridge/L2 und Lasso/L1?
# 18. Warum kann Lasso Koeffizienten exakt auf null setzen?
# 19. Warum setzt Ridge Koeffizienten normalerweise nicht exakt auf null?
# 20. Warum ist Standardisierung vor Ridge oder Lasso wichtig?
# 21. Wann kann zu starke Regularisierung schaden?
# 22. Was bedeutet ein Koeffizient von null fachlich und was bedeutet er nicht?

# %% [markdown]
# ### Deine Antworten
