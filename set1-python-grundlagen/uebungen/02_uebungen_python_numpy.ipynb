# %% [markdown]
# # Übungen 02 – Python und NumPy
# Bearbeite die Aufgaben möglichst ohne die Lösung zu öffnen. Prüfe Zwischenergebnisse mit print oder display.

# %% [markdown]
# ## Aufgabe 1 – Datentypen und Datenstrukturen
# Lege Name, Alter, drei Testergebnisse und den Kursstatus einer Person mit passenden Python-Datentypen ab. Begründe kurz, warum du Liste, Tupel oder Dictionary gewählt hast.

# %%
# Dein Code

# %% [markdown]
# **Deine Begründung:**

# %% [markdown]
# ## Aufgabe 2 – Funktion mit Bedingungen
# Schreibe eine Funktion bewertung(punkte), die ab 90 „sehr gut“, ab 75 „gut“, ab 60 „bestanden“ und darunter „nicht bestanden“ zurückgibt. Teste Grenzwerte.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 – List Comprehension
# Erzeuge aus den Celsius-Werten [-5, 0, 10, 20, 30] eine neue Liste in Fahrenheit. Filtere danach alle Fahrenheit-Werte über 60.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 4 – Array, Form und Reshape
# Erzeuge mit NumPy die Zahlen 1 bis 12 und forme sie zu einer Matrix mit 3 Zeilen und 4 Spalten um. Gib shape, ndim und dtype aus.

# %%
import numpy as np

# Dein Code

# %% [markdown]
# ## Aufgabe 5 – Masken und Kennzahlen
# Für punkte = [55, 72, 88, 49, 91, 67, 76] berechne Mittelwert und Median. Wähle alle Werte zwischen 60 und 80 einschließlich aus und zähle sie.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 6 – Achsen verstehen
# Gegeben ist eine 3×4-Matrix. Berechne Summe je Spalte, Mittelwert je Zeile und den größten Wert der gesamten Matrix. Erkläre die verwendeten axis-Werte.

# %%
matrix = np.array([[2, 4, 6, 8], [1, 3, 5, 7], [10, 20, 30, 40]])
# Dein Code

# %% [markdown]
# **Deine Erklärung:**

# %% [markdown]
# ## Aufgabe 7 – Standardisieren
# Standardisiere das Array [10, 12, 14, 16, 18] manuell: Ziehe den Mittelwert ab und teile durch die Standardabweichung. Prüfe Mittelwert und Standardabweichung des Ergebnisses.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 8 – Reproduzierbarer Zufall
# Erzeuge mit dem Seed 7 zehn ganzzahlige Würfelergebnisse von 1 bis 6. Wiederhole den Vorgang mit einem neuen Generator und demselben Seed. Was beobachtest du?

# %%
# Dein Code

# %% [markdown]
# **Deine Beobachtung:**
