# %% [markdown]
# # Übungen 01 – Einfacher Python-Start
# Kurze Aufgaben zum Setup, zu Notebooks und Bibliotheken.

# %% [markdown]
# ## Aufgabe 1 – Notebook bedienen
# Was ist der Unterschied zwischen einer Textzelle und einer Codezelle? Wie führst du eine Zelle aus?

# %% [markdown]
# **Deine Antwort:**

# %% [markdown]
# ## Aufgabe 2 – Bibliotheken
# Erkläre mit einem einfachen Vergleich, was eine Python-Bibliothek ist. Ordne NumPy, pandas, Matplotlib und scikit-learn jeweils einer Aufgabe zu.

# %% [markdown]
# **Deine Antwort:**

# %% [markdown]
# ## Aufgabe 3 – Virtuelle Umgebung
# Warum verwenden wir für den Kurs eine virtuelle Umgebung? Eine oder zwei einfache Aussagen reichen.

# %% [markdown]
# **Deine Antwort:**

# %% [markdown]
# ## Aufgabe 4 – Reihenfolge
# Bringe diese Schritte in die richtige Reihenfolge: JupyterLab starten, Pakete installieren, virtuelle Umgebung erstellen, virtuelle Umgebung aktivieren.

# %% [markdown]
# **Deine Antwort:**
#
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ## Aufgabe 5 – Standardbibliothek
# Importiere math. Berechne die Quadratwurzel aus 144 und runde Pi auf drei Nachkommastellen.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 6 – NumPy verwenden
# Importiere NumPy als np. Erzeuge ein Array mit [3, 6, 9, 12] und berechne Summe, Mittelwert und Maximum.

# %%
# Dein Code
