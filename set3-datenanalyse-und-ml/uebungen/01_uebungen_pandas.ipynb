# %% [markdown]
# # Übungen 03 – pandas
# Alle Aufgaben verwenden den folgenden kleinen Verkaufsdatensatz. Führe zuerst die Setup-Zelle aus.

# %%
import numpy as np
import pandas as pd

verkaeufe = pd.DataFrame({
    "produkt": ["A", "B", "A", "C", "B", "A", "C", "B"],
    "region": ["Nord", "Süd", "Süd", "Nord", "Nord", "Süd", "Süd", "Nord"],
    "menge": [5, 3, 8, 2, 7, 4, 6, 5],
    "preis": [12.0, 20.0, 12.0, 30.0, np.nan, 12.0, 30.0, 20.0],
    "rabatt_prozent": [0, 10, 5, 0, 10, 0, 15, 5],
})
display(verkaeufe)

# %% [markdown]
# ## Aufgabe 1 – Erkunden
# Gib Form, Spaltennamen, Datentypen, erste drei Zeilen und deskriptive Kennzahlen aus. Welche Datenqualitätsfrage fällt sofort auf?

# %%
# Dein Code

# %% [markdown]
# **Deine Beobachtung:**

# %% [markdown]
# ## Aufgabe 2 – Auswählen und filtern
# Zeige nur Produkt, Region und Menge. Filtere anschließend alle Verkäufe aus Region Süd mit einer Menge von mindestens 5.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 – Fehlenden Wert behandeln
# Finde fehlende Werte. Ersetze den fehlenden Preis durch den Medianpreis des zugehörigen Produkts. Arbeite auf einer Kopie. Begründe, weshalb diese Strategie hier sinnvoller sein kann als der globale Mittelwert.

# %%
# Dein Code

# %% [markdown]
# **Deine Begründung:**

# %% [markdown]
# ## Aufgabe 4 – Merkmal erzeugen
# Berechne eine neue Spalte umsatz_netto: menge × preis × (1 − rabatt_prozent / 100). Runde auf zwei Nachkommastellen.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 5 – Gruppieren
# Ermittle je Region die Zahl der Verkäufe, die Gesamtmenge und den gesamten Nettoumsatz. Sortiere nach Nettoumsatz absteigend.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 6 – Produktanalyse
# Bestimme für jedes Produkt den mittleren Rabatt und den Nettoumsatz. Welches Produkt erzielt den höchsten Nettoumsatz?

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 7 – Visualisieren
# Erzeuge ein Balkendiagramm des Nettoumsatzes je Produkt. Ergänze Titel und Achsenbeschriftungen.

# %%
import matplotlib.pyplot as plt

# Dein Code

# %% [markdown]
# ## Aufgabe 8 – Reflexion
# Weshalb beweist ein höherer Umsatz in einer Region nicht, dass die Region ursächlich für den Umsatz ist? Nenne zwei weitere Informationen, die du für eine faire Bewertung benötigen könntest.

# %% [markdown]
# **Deine Antwort:**
