# %% [markdown]
# # Übungen 04 – scikit-learn
# Baue einen Klassifikationsworkflow für den eingebauten Wine-Datensatz. Kein Download ist nötig.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine

wine = load_wine(as_frame=True)
X = wine.data
y = wine.target

# %% [markdown]
# ## Aufgabe 1 – Problem und Daten verstehen
# Ist dies Klassifikation oder Regression? Was bedeuten X und y? Gib Formen, Klassenverteilung, fehlende Werte und deskriptive Kennzahlen aus. Nenne ein mögliches Problem, falls eine Klasse sehr selten wäre.

# %%
# Dein Code

# %% [markdown]
# **Deine Textantwort:**

# %% [markdown]
# ## Aufgabe 2 – Daten aufteilen
# Erzeuge 75 % Trainings- und 25 % Testdaten. Nutze random_state=42 und erhalte die Klassenanteile. Erkläre, warum das Modell die Testdaten nicht beim Training sehen darf.

# %%
from sklearn.model_selection import train_test_split

# Dein Code

# %% [markdown]
# **Deine Erklärung:**

# %% [markdown]
# ## Aufgabe 3 – Pipeline trainieren
# Erstelle eine Pipeline aus StandardScaler und LogisticRegression mit höchstens 2000 Iterationen. Trainiere sie auf den Trainingsdaten. Warum ist die Pipeline sicherer als das Skalieren des gesamten Datensatzes vor dem Split?

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Dein Code

# %% [markdown]
# **Deine Erklärung:**

# %% [markdown]
# ## Aufgabe 4 – Bewerten
# Erzeuge Vorhersagen für den Testsatz. Berechne Accuracy und einen Klassifikationsbericht. Zeichne zusätzlich die Konfusionsmatrix. Welche Fehler macht das Modell?

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, classification_report

# Dein Code

# %% [markdown]
# **Deine Interpretation:**

# %% [markdown]
# ## Aufgabe 5 – Kreuzvalidierung
# Berechne die Accuracy mit 5-facher Kreuzvalidierung auf dem gesamten Datensatz. Gib alle Scores, Mittelwert und Standardabweichung aus. Warum ist das oft stabiler als ein einzelner Split?

# %%
from sklearn.model_selection import cross_val_score

# Dein Code

# %% [markdown]
# **Deine Erklärung:**

# %% [markdown]
# ## Aufgabe 6 – Baseline und Vergleich
# Trainiere einen DummyClassifier mit der Strategie most_frequent und vergleiche seine 5-fache CV-Accuracy mit dem echten Modell. Was zeigt dieser Vergleich?

# %%
from sklearn.dummy import DummyClassifier

# Dein Code

# %% [markdown]
# **Deine Interpretation:**

# %% [markdown]
# ## Aufgabe 7 – Verantwortung und Grenzen
# Nenne mindestens drei Gründe, warum ein guter Testwert noch nicht beweist, dass ein Modell in der Praxis zuverlässig oder fair ist.

# %% [markdown]
# **Deine Antwort:**
