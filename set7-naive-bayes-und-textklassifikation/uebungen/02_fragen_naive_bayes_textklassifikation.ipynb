# %% [markdown]
# # Fragen – Naive Bayes und Textklassifikation

# %% [markdown]
# ## Bayes-Grundlagen
#
# 1. Was bedeuten Prior, Likelihood und Posterior?
# 2. Welche Klasse wählt die Bayes-Entscheidungsregel?
# 3. Was ist die naive Unabhängigkeitsannahme?
# 4. Warum kann Naive Bayes trotz unrealistischer Annahme gut funktionieren?
# 5. Welche Parameter lernt Gaussian Naive Bayes?
# 6. Wann ist die Normalverteilungsannahme unpassend?
# 7. Was unterscheidet GaussianNB und MultinomialNB?
# 8. Welche Rolle spielt der Glättungsparameter alpha?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## Vergleich mit logistischer Regression
#
# 9. Was bedeutet generativ und was diskriminativ?
# 10. Welche Verteilungen modelliert Naive Bayes?
# 11. Was lernt logistische Regression direkt?
# 12. Welches Modell erzeugt bei zwei Merkmalen zwingend eine lineare Grenze?
# 13. Warum kann Naive Bayes bei wenig Textdaten stark sein?
# 14. Warum können stark korrelierte Merkmale Naive Bayes Probleme bereiten?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## Textmerkmale und Auswahl
#
# 15. Was ist ein Bag-of-Words-Modell?
# 16. Was machen fit(), transform() und fit_transform() bei CountVectorizer?
# 17. Was ist der Unterschied zwischen Unigramm und Bigramm?
# 18. Warum wird die Textmatrix als Sparse Matrix gespeichert?
# 19. Was bewirken min_df und max_features?
# 20. Wie funktioniert SelectKBest mit Chi² grundsätzlich?
# 21. Warum muss die Feature Selection innerhalb der Pipeline liegen?
# 22. Welchen Vorteil und welches Risiko besitzt manuelle Wortauswahl?
# 23. Warum sollte der Spamfilter nicht nur mit Accuracy bewertet werden?
# 24. Was können False Positives und False Negatives im Spamkontext bedeuten?
# 25. Warum muss ein realer Spamfilter nach dem Deployment überwacht werden?

# %% [markdown]
# ### Deine Antworten
