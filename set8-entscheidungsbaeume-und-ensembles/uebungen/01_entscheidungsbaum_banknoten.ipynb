# %% [markdown]
# # Übung 1 - Entscheidungsbaum auf Banknotendaten
#
# Alle drei Modellnotebooks verwenden denselben Split (`test_size=0.25`, `random_state=42`, `stratify=y`). Nur so sind die Ergebnisse in Notebook 4 fair vergleichbar. Die Zielwerte heißen bewusst Klasse 0 und 1.

# %%
from pathlib import Path
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay,accuracy_score,f1_score,precision_score,recall_score,roc_auc_score
from sklearn.model_selection import GridSearchCV,train_test_split
pfade=[Path("../daten/banknote_authentication.csv"),Path("set8-entscheidungsbaeume-und-ensembles/daten/banknote_authentication.csv")]
pfad=next((p for p in pfade if p.exists()),None)
if pfad is None: raise FileNotFoundError("banknote_authentication.csv fehlt")
daten=pd.read_csv(pfad); X=daten.drop(columns="klasse"); y=daten["klasse"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=42,stratify=y)
daten.head()
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %% [markdown]
# ## Aufgabe 1 - Daten verstehen
#
# Prüfe Form, Datentypen, fehlende Werte, Klassenanteile und Verteilungen. Welche Merkmale trennen die Klassen sichtbar?

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 2 - Baseline
#
# Trainiere einen unbeschränkten Baum. Berechne Accuracy, Precision, Recall, F1 und ROC-AUC. Vergleiche Training- und Test-F1.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 - Grid Search
#
# Suche mit fünf Folds und `scoring="f1"` über `criterion`, `max_depth`, `min_samples_leaf` und optional `ccp_alpha`. Der Testdatensatz bleibt unberührt.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 4 - Erklären
#
# Bewerte das beste Modell. Zeige Konfusionsmatrix, erste Baumebenen und Feature Importances.

# %%
# Dein Code

# %% [markdown]
# ### Ergebnisblock zum Übertragen
#
# - Modell:
# - CV-F1:
# - Test-Accuracy:
# - Test-Precision:
# - Test-Recall:
# - Test-F1:
# - Test-ROC-AUC:
# - Suchzeit:
# - Beste Parameter:
# - Wichtigste Beobachtung:
