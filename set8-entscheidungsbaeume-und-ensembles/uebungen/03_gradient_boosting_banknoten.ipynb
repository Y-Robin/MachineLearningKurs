# %% [markdown]
# # Übung 3 - Gradient Boosting auf Banknotendaten
#
# Alle drei Modellnotebooks verwenden denselben Split (`test_size=0.25`, `random_state=42`, `stratify=y`). Nur so sind die Ergebnisse in Notebook 4 fair vergleichbar. Die Zielwerte heißen bewusst Klasse 0 und 1.

# %%
from pathlib import Path
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay,accuracy_score,f1_score,precision_score,recall_score,roc_auc_score
from sklearn.model_selection import GridSearchCV,train_test_split
pfade=[Path("../daten/banknote_authentication.csv"),Path("set8-entscheidungsbaeume-und-ensembles/daten/banknote_authentication.csv")]
pfad=next((p for p in pfade if p.exists()),None)
if pfad is None: raise FileNotFoundError("banknote_authentication.csv fehlt")
daten=pd.read_csv(pfad); X=daten.drop(columns="klasse"); y=daten["klasse"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=42,stratify=y)
daten.head()
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import log_loss

# %% [markdown]
# ## Aufgabe 1 - Lernverlauf
#
# Trainiere ein Standardmodell und zeichne mit `staged_predict_proba` Training- und Test-Log-Loss über die Zahl der Bäume.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 2 - Grid Search
#
# Suche gemeinsam über `learning_rate`, `n_estimators`, `max_depth` und `subsample`. Erkläre das Zusammenspiel der ersten beiden.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 - Auswerten
#
# Berechne dieselben Testmetriken, Konfusionsmatrix und Feature Importances. Beurteile Laufzeit und Empfindlichkeit.

# %%
# Dein Code

# %% [markdown]
# ### Ergebnisblock zum Übertragen
#
# - Modell:
# - CV-F1:
# - Test-Accuracy:
# - Test-Precision:
# - Test-Recall:
# - Test-F1:
# - Test-ROC-AUC:
# - Suchzeit:
# - Beste Parameter:
# - Wichtigste Beobachtung:
