# %% [markdown]
# # Übung 4 - Vergleich und Fragen
#
# Übertrage die Ergebnisse der drei Modellnotebooks. Gleicher Split und gleiche Metriken sind Voraussetzung.

# %%
import pandas as pd
vergleich=pd.DataFrame([
{"Modell":"Entscheidungsbaum","CV-F1":None,"Test-F1":None,"ROC-AUC":None,"Suchzeit_s":None},
{"Modell":"Random Forest","CV-F1":None,"Test-F1":None,"ROC-AUC":None,"Suchzeit_s":None},
{"Modell":"Gradient Boosting","CV-F1":None,"Test-F1":None,"ROC-AUC":None,"Suchzeit_s":None}]).set_index("Modell")
vergleich

# %% [markdown]
# ## A - Entscheidungsbäume
#
# 1. Was lernt ein innerer Knoten?
# 2. Was bedeutet ein reiner Knoten?
# 3. Wie unterscheiden sich Gini und Entropie?
# 4. Was sagt ein Regressionsbaum im Blatt vorher?
# 5. Warum ist Baumtraining greedy?
# 6. Unterschied zwischen `min_samples_split` und `min_samples_leaf`?
# 7. Wie wirken `max_depth` und `ccp_alpha` auf Bias und Varianz?
# 8. Warum brauchen Bäume meist keine Standardisierung?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## B - Ensembles
#
# 9. Was ist Ensemble Learning?
# 10. Was ist Bootstrap Sampling?
# 11. Warum nutzt der Forest nur einen Teil der Merkmale pro Split?
# 12. Was ist eine OOB-Beobachtung?
# 13. Warum ist ein Forest stabiler als ein Einzelbaum?
# 14. Wie unterscheiden sich Forest- und Boosting-Training?
# 15. Warum nutzt Boosting oft flache Bäume?
# 16. Zusammenhang von `learning_rate` und `n_estimators`?
# 17. Was bewirkt `subsample < 1`?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## C - Deine Experimente vergleichen
#
# 18. Welches Modell hat höchsten CV-F1 und Test-F1?
# 19. Sind Unterschiede praktisch relevant?
# 20. Welche Fehlertypen zeigen die Konfusionsmatrizen?
# 21. Stimmen CV und Test überein? Was erklärt Abweichungen?
# 22. Welches Modell war am schnellsten?
# 23. Welches ist als vollständige Regel am einfachsten erklärbar?
# 24. Stimmen Feature Importances überein?
# 25. Welches Modell wählst du bezüglich Leistung, Stabilität, Laufzeit und Erklärbarkeit?
# 26. Warum darf der Testdatensatz nicht beim Tuning helfen?
# 27. Welche Prüfungen fehlen vor echtem Einsatz?

# %% [markdown]
# ### Deine Antworten und Modellentscheidung
