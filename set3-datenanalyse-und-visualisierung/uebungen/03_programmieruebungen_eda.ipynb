# %% [markdown]
# # Programmierübungen – Explorative Datenanalyse
# Löse die Aufgaben mit pandas und Matplotlib. Es werden keine Vorhersagen und keine ML-Modelle erstellt.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

def datenpfad(name):
    kandidaten=[Path("daten")/name,Path("set3-datenanalyse-und-visualisierung/daten")/name,Path("../daten")/name,Path("../../daten")/name]
    return next(p for p in kandidaten if p.exists())

# %% [markdown]
# ## Aufgabe 1 – Drei Datensätze einlesen
# Lies alle drei CSV-Dateien ein. Beachte das Trennzeichen beim Weindatensatz. Gib jeweils Form und erste drei Zeilen aus.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 2 – Qualitätsbericht
# Erzeuge für jeden Datensatz eine kleine Tabelle mit Zeilen, Spalten, fehlenden Werten und vollständig identischen Zeilen.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 – Pinguine
# Berechne je Art Anzahl, mittlere Körpermasse und mittlere Flossenlänge. Zeichne die Körpermasse als Boxplot nach Art und einen Scatterplot von Flossenlänge gegen Körpermasse, farbig nach Art.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 4 – Fehlende Werte
# Zeige für die Pinguine Anzahl und Anteil fehlender Werte pro Spalte. Erstelle danach eine bereinigte Kopie, in der nur Zeilen ohne Körpermaße entfernt werden. Vergleiche vorherige und neue Zeilenzahl.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 5 – Weinqualität
# Zeichne die Häufigkeit jeder Qualitätsstufe. Berechne je Qualitätsstufe Median von Alkohol und flüchtiger Säure. Visualisiere beide Größen mit Boxplots.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 6 – Korrelationen
# Bestimme beim Wein die fünf Merkmale mit der betragsmäßig stärksten Korrelation zur Qualitätsbewertung. Formuliere anschließend zwei vorsichtige Interpretationen.

# %%
# Dein Code

# %% [markdown]
# **Deine Interpretationen:**

# %% [markdown]
# ## Aufgabe 7 – Maschinenzustände
# Berechne Anzahl und prozentualen Anteil der Ausfälle. Ermittle die Ausfallrate je Produkttyp und zeichne sie als Balkendiagramm.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 8 – Faire Visualisierung
# Erstelle für Drehmoment getrennte Histogramme für Normalfälle und Ausfälle. Nutze dieselben Klassenintervalle und Achsengrenzen. Warum ist diese Vergleichbarkeit wichtig?

# %%
# Dein Code

# %% [markdown]
# **Deine Erklärung:**

# %% [markdown]
# ## Aufgabe 9 – Eigene Untersuchung
# Formuliere eine eigene Frage zu einem Datensatz, wähle passende Kennzahlen und ein Diagramm und beantworte die Frage vorsichtig. Trenne Beobachtung und Interpretation.

# %%
# Dein Code

# %% [markdown]
# **Beobachtung:**
#
# **Interpretation und Grenzen:**
