# %% [markdown]
# # Fragen – Datenanalyse und Visualisierung
# Beantworte in eigenen Worten. Die Fragen beziehen sich auf das Set-03-Skript und die drei Beispieldatensätze.

# %% [markdown]
# ## Daten verstehen
# 1. Was ist in einer Tabelle ein Sample und was ist ein Merkmal?
# 2. Woran erkennt man einen möglichen Zielwert?
# 3. Warum sollten IDs nicht automatisch als numerische Messwerte analysiert werden?
# 4. Welche Informationen gehören zu einer guten Datensatzdokumentation?
# 5. Was unterscheidet Beobachtungsdaten von experimentellen Daten?

# %% [markdown]
# ### Antworten
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %% [markdown]
# ## Datenqualität
# 6. Welche Prüfungen führst du unmittelbar nach dem Einlesen einer CSV-Datei durch?
# 7. Warum darf man fehlende Werte nicht immer einfach löschen?
# 8. Warum sind identische Zeilen nicht automatisch fehlerhafte Duplikate?
# 9. Was bedeutet Repräsentativität?
# 10. Welche Besonderheit zeigt die Verteilung von Machine failure?

# %% [markdown]
# ### Antworten
#
# 6.
#
# 7.
#
# 8.
#
# 9.
#
# 10.

# %% [markdown]
# ## Diagramme und Korrelation
# 11. Welches Diagramm eignet sich für Häufigkeiten von Kategorien?
# 12. Was zeigt ein Histogramm, was ein Boxplot und was ein Scatterplot?
# 13. Warum ist eine Achsenbeschriftung mit Einheit wichtig?
# 14. Was bedeutet eine positive, negative oder nahe null liegende Korrelation?
# 15. Warum beweist Korrelation keine Ursache?
# 16. Wie können Gruppenunterschiede eine Gesamtkorrelation beeinflussen?

# %% [markdown]
# ### Antworten
#
# 11.
#
# 12.
#
# 13.
#
# 14.
#
# 15.
#
# 16.

# %% [markdown]
# ## Datensätze und Lizenzen
# 17. Welcher der drei Datensätze enthält fehlende Werte?
# 18. Welcher Datensatz ist synthetisch und warum ist das wichtig?
# 19. Warum reicht die Angabe kommerziell nutzbar allein nicht aus?
# 20. Was verlangt CC BY 4.0 zusätzlich zu CC0?

# %% [markdown]
# ### Antworten
#
# 17.
#
# 18.
#
# 19.
#
# 20.
