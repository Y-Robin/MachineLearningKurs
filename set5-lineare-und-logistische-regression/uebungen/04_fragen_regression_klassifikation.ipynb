# %% [markdown]
# # Fragen – Lineare und logistische Regression

# %% [markdown]
# ## Lineare Regression
#
# 1. Woran erkennst du ein Regressionsproblem?
# 2. Welche Bedeutung haben m und b bei genau einem Merkmal?
# 3. Was ist ein Residuum?
# 4. Warum werden Residuen bei Least Squares quadriert?
# 5. Was unterscheidet MAE und RMSE?
# 6. Was bedeutet ein R² nahe 1, nahe 0 oder kleiner als 0?
# 7. Warum kann Extrapolation problematisch sein?
# 8. Wie beeinflussen starke Ausreißer die Regressionsgerade?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## Logistische Regression
#
# 9. Warum ist lineare Regression keine gute Lösung für binäre Klassen?
# 10. Welche Aufgabe hat die Sigmoid-Funktion?
# 11. Was ist der Unterschied zwischen predict() und predict_proba()?
# 12. Was bedeuten True Positive und False Negative?
# 13. Wie wird Recall berechnet und wann ist er wichtig?
# 14. Wie verändert ein niedrigerer Schwellenwert typischerweise Recall und Precision?
# 15. Was zeigt eine Konfusionsmatrix?
# 16. Was zeigt die ROC-Kurve?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## scikit-learn und Pipeline
#
# 17. Was tun fit(), transform(), fit_transform() und predict()?
# 18. Warum darf der Scaler nicht auf dem vollständigen Datensatz gefittet werden?
# 19. Warum ist stratify bei unausgeglichenen Klassen nützlich?
# 20. Welche Aufgabe haben Pipeline und ColumnTransformer?
# 21. Warum muss die Zielvariable vor der Vorverarbeitung aus X entfernt werden?
# 22. Welche zusätzlichen Fragen sind bei einem real eingesetzten Modell nötig?

# %% [markdown]
# ### Deine Antworten
