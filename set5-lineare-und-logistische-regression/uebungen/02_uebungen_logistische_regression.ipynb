# %% [markdown]
# # Übungen – Logistische Regression
#
# Aufgabe ist die Erkennung einer selteneren Klasse in kontrollierten Sensordaten. Untersuche besonders den Einfluss des Schwellenwerts auf Recall und Precision.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

X_array, y_array = make_classification(
    n_samples=500, n_features=2, n_informative=2, n_redundant=0,
    n_clusters_per_class=1, weights=[0.8, 0.2],
    class_sep=1.0, flip_y=0.05, random_state=17
)
X = pd.DataFrame(X_array, columns=["sensor_a", "sensor_b"])
y = pd.Series(y_array, name="alarm")

# %% [markdown]
# ## Aufgabe 1 – Klassen prüfen und visualisieren
#
# Gib absolute und relative Häufigkeiten aus. Zeichne beide Klassen in unterschiedlichen Farben.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 2 – Stratifizierter Split
#
# Teile 75 Prozent Training und 25 Prozent Test. Begründe stratify=y.

# %%
# Dein Code

# %% [markdown]
# **Deine Begründung:**

# %% [markdown]
# ## Aufgabe 3 – Pipeline
#
# Erstelle eine Pipeline aus StandardScaler und LogisticRegression. Fitte ausschließlich mit Trainingsdaten.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 4 – Wahrscheinlichkeiten und Vorhersagen
#
# Berechne predict() und die Wahrscheinlichkeit für Klasse 1. Zeige zehn Fälle als Tabelle.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 5 – Metriken
#
# Berechne Accuracy, Precision, Recall, F1 und eine Konfusionsmatrix. Welche Fehlerart ist bei einem sicherheitskritischen Alarm besonders problematisch?

# %%
# Dein Code

# %% [markdown]
# **Deine Antwort:**

# %% [markdown]
# ## Aufgabe 6 – Schwellenwerte
#
# Vergleiche 0,25, 0,50 und 0,75. Erstelle eine Tabelle mit Precision, Recall, F1 und Anzahl positiver Vorhersagen.

# %%
# Dein Code

# %% [markdown]
# **Welchen Trade-off erkennst du?**

# %% [markdown]
# ## Aufgabe 7 – ROC
#
# Zeichne die ROC-Kurve und berechne ROC-AUC.

# %%
# Dein Code
