# %% [markdown]
# # Übungen – Lineare Regression
#
# Schätze die Lieferzeit aus der Entfernung. Bearbeite die Zellen zunächst selbst und formuliere Interpretationen in eigenen Worten.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

rng = np.random.default_rng(9)
entfernung = rng.uniform(1, 35, 140)
lieferzeit = 12 + 2.4 * entfernung + rng.normal(0, 7, len(entfernung))
daten = pd.DataFrame({
    "entfernung_km": entfernung.round(2),
    "lieferzeit_min": lieferzeit.round(2),
})

# %% [markdown]
# ## Aufgabe 1 – Visualisieren
#
# Erstelle einen Scatterplot und beschrifte beide Achsen. Ist ein linearer Zusammenhang plausibel?

# %%
# Dein Code

# %% [markdown]
# **Deine Einschätzung:**

# %% [markdown]
# ## Aufgabe 2 – Aufteilen
#
# Bilde X und y. Teile 75 Prozent Training und 25 Prozent Test mit random_state=42.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 – Fitten
#
# Erzeuge LinearRegression, fitte nur mit den Trainingsdaten und gib Steigung sowie Achsenabschnitt aus.

# %%
# Dein Code

# %% [markdown]
# **Interpretiere die Steigung in Minuten pro Kilometer:**

# %% [markdown]
# ## Aufgabe 4 – Bewerten
#
# Berechne Vorhersagen für den Testdatensatz sowie MAE, RMSE und R². Erkläre die Werte mit ihren Einheiten.

# %%
# Dein Code

# %% [markdown]
# **Deine Interpretation:**

# %% [markdown]
# ## Aufgabe 5 – Gerade und Residuen
#
# Zeichne die Regressionsgerade über die Punkte. Erstelle danach einen Residuenplot mit Nulllinie.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 6 – Neue Lieferung
#
# Schätze die Lieferzeit für 20 Kilometer. Übergib den Wert als DataFrame mit passendem Spaltennamen.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 7 – Transfer
#
# Nenne zwei Gründe, warum das Modell in einer realen Stadt schlechter funktionieren könnte als in diesen kontrollierten Daten.

# %% [markdown]
# **Deine Antwort:**
