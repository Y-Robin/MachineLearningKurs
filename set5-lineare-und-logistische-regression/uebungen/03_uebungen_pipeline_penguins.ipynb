# %% [markdown]
# # Übungen – Vollständige Pipeline mit Palmer Penguins
#
# Baue den kompletten Workflow möglichst selbst nach. Der CC0-Datensatz wird aus dem offiziellen Projekt geladen; bei fehlendem Internet kannst du die lokale Set-03-Kopie verwenden.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

URL = "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/main/inst/extdata/penguins.csv"
try:
    daten = pd.read_csv(URL)
except Exception:
    kandidaten = [
        Path("../set3-datenanalyse-und-visualisierung/daten/palmer_penguins.csv"),
        Path("set3-datenanalyse-und-visualisierung/daten/palmer_penguins.csv"),
    ]
    pfad = next(p for p in kandidaten if p.exists())
    daten = pd.read_csv(pfad)

daten.head()

# %% [markdown]
# ## Aufgabe 1 – Analyse
#
# Prüfe Form, Datentypen, fehlende Werte und Häufigkeit der Arten. Visualisiere mindestens zwei Körpermaße nach Art.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 2 – X, y und Split
#
# Verwende island, vier Körpermaße und sex als Merkmale. Teile stratifiziert in 75 Prozent Training und 25 Prozent Test.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 – Vorverarbeitung
#
# Baue eine numerische Pipeline mit Median-Imputation und Skalierung sowie eine kategoriale Pipeline mit häufigster Kategorie und One-Hot-Encoding.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 4 – Gesamt-Pipeline
#
# Verbinde ColumnTransformer und LogisticRegression in einer Pipeline und fitte die Trainingsdaten.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 5 – Bewertung
#
# Erzeuge einen Classification Report und eine Konfusionsmatrix. Welche Art hat den niedrigsten Recall?

# %%
# Dein Code

# %% [markdown]
# **Deine Interpretation:**

# %% [markdown]
# ## Aufgabe 6 – Transparenz
#
# Gib die Namen und die Anzahl der transformierten Modellmerkmale aus.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 7 – Neue Rohdaten
#
# Erfinde einen plausiblen neuen Pinguin. Lass Art und Klassenwahrscheinlichkeiten von der Pipeline ausgeben.

# %%
# Dein Code
