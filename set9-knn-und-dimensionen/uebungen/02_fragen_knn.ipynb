# %% [markdown]
# # Fragen - KNN, Distanzen und hohe Dimensionen

# %% [markdown]
# ## Grundlagen
#
# 1. Warum wird KNN als Lazy Learner bezeichnet?
# 2. Was speichert `fit()` bei KNN im Wesentlichen?
# 3. Wie entstehen Klassifikations- und Regressionsvorhersagen?
# 4. Wie wirkt ein sehr kleines beziehungsweise sehr großes k?
# 5. Was unterscheidet `uniform` und `distance`?
# 6. Was bedeuten `metric="minkowski"` sowie `p=1` und `p=2`?
# 7. Was berücksichtigt Mahalanobis zusätzlich?
# 8. Wann kann Mahalanobis problematisch sein?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## Pipeline und Bewertung
#
# 9. Warum ist Skalierung für KNN besonders wichtig?
# 10. Warum gehören Scaler, Feature Selection und KNN in dieselbe Pipeline?
# 11. Was wäre Data Leakage bei der Skalierung?
# 12. Warum wird k per Cross-Validation statt Testdaten gewählt?
# 13. Welche KNN-Parameter würdest du zuerst abstimmen?
# 14. Warum kann Accuracy bei ungleichen Klassen irreführen?
# 15. Was bedeuten False Positive und False Negative im Übungsdatensatz?
# 16. Warum ist ein hoher Testscore keine klinische Freigabe?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## Curse of Dimensionality und Praxis
#
# 17. Warum wächst der Merkmalsraum mit jeder Dimension so stark?
# 18. Was bedeutet, dass Daten in hohen Dimensionen dünn werden?
# 19. Warum nähern sich nächste und ferne Distanzen relativ an?
# 20. Warum können irrelevante Features KNN stark verschlechtern?
# 21. Wie helfen Feature Selection und Dimensionsreduktion?
# 22. Warum ist weniger nicht automatisch besser?
# 23. Warum kann KNN bei der Vorhersage langsam sein?
# 24. Wie beeinflussen `algorithm` und `leaf_size` die Laufzeit, aber nicht direkt die fachliche Modellkomplexität?
# 25. Wann würdest du statt KNN eine andere Modellfamilie wählen?
# 26. Welche Beobachtungen aus deinem Projekt belegen den Curse of Dimensionality?

# %% [markdown]
# ### Deine Antworten
