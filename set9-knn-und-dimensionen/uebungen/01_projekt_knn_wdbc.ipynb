# %% [markdown]
# # Projekt - KNN, Skalierung und Dimensionen
#
# Baue eine vollständige KNN-Pipeline auf dem 30-dimensionalen UCI-WDBC-Datensatz. Die Aufgabe dient ausschließlich dem Erlernen von ML-Technik und nicht medizinischen Entscheidungen.

# %%
from pathlib import Path
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest,f_classif
from sklearn.metrics import ConfusionMatrixDisplay,accuracy_score,f1_score,precision_score,recall_score,roc_auc_score
from sklearn.model_selection import GridSearchCV,train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
pfade=[Path("../daten/wdbc.csv"),Path("set9-knn-und-dimensionen/daten/wdbc.csv")]
pfad=next((p for p in pfade if p.exists()),None)
if pfad is None: raise FileNotFoundError("wdbc.csv fehlt")
daten=pd.read_csv(pfad); X=daten.drop(columns=["id","diagnose"]); y=daten["diagnose"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=42,stratify=y)
daten.head()

# %% [markdown]
# ## Aufgabe 1 - Daten verstehen
#
# Prüfe Form, fehlende Werte, Klassenverteilung, Skalen und Korrelationen. Warum ist KNN ohne Skalierung hier problematisch?

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 2 - Faire Baselines
#
# Vergleiche `KNeighborsClassifier(n_neighbors=5)` ohne Skalierung mit einer Pipeline aus `StandardScaler` und KNN. Verwende Accuracy, Precision, Recall, F1, ROC-AUC und eine Konfusionsmatrix.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 - Grid Search mit Feature Selection
#
# Erstelle `StandardScaler -> SelectKBest(f_classif) -> KNN`. Suche mit fünf Folds und `scoring="f1"` über die Zahl ausgewählter Merkmale, `n_neighbors`, `weights` und `p`. Fitte nur Trainingsdaten.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 4 - Curse of Dimensionality
#
# Füge Training und Test mit festem Zufallsseed 200 reine Rauschmerkmale hinzu. Vergleiche KNN mit allen 230 Merkmalen gegen eine innerhalb der Pipeline gelernte Feature Selection. Warum darf der Selector nicht vor dem Split gefittet werden?

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 5 - Modell verstehen
#
# Gib die ausgewählten Originalmerkmale aus. Zeige für einen Testfall seine nächsten Nachbarn, Distanzen und Klassen. Wie verändert `weights="distance"` deren Einfluss?

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 6 - Fazit
#
# Vergleiche unskaliert, skaliert, abgestimmt, mit Rauschmerkmalen und mit erneuter Auswahl. Begründe deine finale Konfiguration mit Validierungsleistung, Testfehlern, Dimensionalität und Rechenaufwand.

# %%
# Dein Code
