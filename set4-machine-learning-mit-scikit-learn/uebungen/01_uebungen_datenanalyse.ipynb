# %% [markdown]
# # Übungen – Daten verstehen und visualisieren
#
# Bearbeite die Aufgaben zunächst selbst. Es gibt keine Zielvariable und kein Modell; konzentriere dich auf Struktur, Qualität und verständliche Visualisierungen.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

rng = np.random.default_rng(7)
n = 180
kurse = pd.DataFrame({
    "lernzeit_stunden": np.clip(rng.normal(6, 2.2, n), 1, 14).round(1),
    "anwesenheit_prozent": np.clip(rng.normal(83, 11, n), 40, 100).round(1),
    "uebungen_abgegeben": rng.integers(0, 11, n),
    "kursformat": rng.choice(["Online", "Präsenz", "Hybrid"], n, p=[0.4, 0.35, 0.25]),
    "standort": rng.choice(["Berlin", "Köln", "Hamburg"], n),
})
kurse.loc[rng.choice(n, 10, replace=False), "lernzeit_stunden"] = np.nan
kurse.loc[rng.choice(n, 7, replace=False), "kursformat"] = np.nan
kurse.loc[12, "anwesenheit_prozent"] = 15

# %% [markdown]
# ## Aufgabe 1 – Erster Überblick
#
# Zeige die ersten fünf und drei zufällige Zeilen. Gib Form, Spaltennamen und Datentypen aus. Formuliere danach zwei Beobachtungen.

# %%
# Dein Code

# %% [markdown]
# **Deine Beobachtungen:**

# %% [markdown]
# ## Aufgabe 2 – Datenqualität
#
# Zähle fehlende Werte. Suche außerdem nach mindestens einem fachlich auffälligen Wert. Erkläre, warum auffällig nicht automatisch falsch bedeutet.

# %%
# Dein Code

# %% [markdown]
# **Deine Erklärung:**

# %% [markdown]
# ## Aufgabe 3 – Numerische Beschreibung
#
# Wähle nur numerische Spalten aus und verwende describe(). Vergleiche Mittelwert, Median und Maximum der Anwesenheit.

# %%
# Dein Code

# %% [markdown]
# **Deine Interpretation:**

# %% [markdown]
# ## Aufgabe 4 – Kategorien
#
# Zähle Kursformate inklusive fehlender Werte. Berechne zusätzlich die prozentualen Anteile der Standorte.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 5 – Visualisieren
#
# Erstelle:
# 1. ein Histogramm der Lernzeit,
# 2. einen Boxplot der Anwesenheit,
# 3. ein Balkendiagramm der mittleren Lernzeit je Kursformat.
#
# Beschrifte Titel und Achsen.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 6 – Zusammenhänge
#
# Erstelle einen Scatterplot für Lernzeit und abgegebene Übungen sowie eine Korrelationsmatrix der numerischen Spalten. Welche Aussage ist zulässig und welche nicht?

# %%
# Dein Code

# %% [markdown]
# **Deine Antwort:**
