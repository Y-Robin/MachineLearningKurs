# %% [markdown]
# # Programmierübungen – Vorverarbeitung mit scikit-learn
#
# Baue schrittweise eine reine Vorverarbeitungs-Pipeline. Es gibt absichtlich keine Zielvariable und kein Modell.

# %%
import numpy as np
import pandas as pd

roh_daten = pd.DataFrame({
    "flaeche_qm": [45, 72, np.nan, 105, 63, 88, 51, np.nan],
    "baujahr": [1998, 2012, 1985, np.nan, 2005, 1972, 2020, 1991],
    "stadtteil": ["Nord", "Mitte", "Süd", "Mitte", np.nan, "Nord", "Süd", "Mitte"],
    "heizart": ["Gas", "Fernwärme", "Öl", "Gas", "Fernwärme", np.nan, "Wärmepumpe", "Gas"],
})
roh_daten

# %% [markdown]
# ## Aufgabe 1 – Analysieren
#
# Gib Form, Datentypen, fehlende Werte, numerische Kennzahlen und Häufigkeiten der Kategorien aus.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 2 – Einzelne Transformer
#
# Imputiere numerische Spalten mit dem Median und skaliere sie. Gib die gelernten Medianwerte, Mittelwerte und die transformierte Zahlentabelle aus.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 – Kategorien vorbereiten
#
# Ersetze fehlende Kategorien durch die häufigste Ausprägung und one-hot-codiere sie. Verwende handle_unknown="ignore" und gib die neuen Spaltennamen aus.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 4 – Zwei Pipelines
#
# Erstelle eine numerische Pipeline aus SimpleImputer und StandardScaler sowie eine kategoriale Pipeline aus SimpleImputer und OneHotEncoder.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 5 – ColumnTransformer und Gesamt-Pipeline
#
# Ordne beide Spaltengruppen mit ColumnTransformer zu. Verpacke ihn in einer Pipeline, führe fit_transform() aus und stelle das Ergebnis als DataFrame mit verständlichen Spaltennamen dar.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 6 – Neue Daten
#
# Transformiere zwei neue Wohnungen. Eine soll einen fehlenden Zahlenwert enthalten, die andere den neuen Stadtteil West. Verwende nur transform(). Prüfe, ob die Ausgabe gleich viele Spalten wie zuvor besitzt.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 7 – Reflektieren
#
# Welche Teile der Pipeline lernen Informationen aus Daten? Was müsste an Tag 5 beachtet werden, bevor ein Modell ergänzt wird?

# %% [markdown]
# **Deine Antwort:**
