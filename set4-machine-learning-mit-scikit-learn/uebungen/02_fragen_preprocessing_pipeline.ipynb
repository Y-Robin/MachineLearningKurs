# %% [markdown]
# # Fragen – Splits, Preprocessing und Pipelines
# Beantworte die Fragen in eigenen Worten und begründe möglichst mit einem Beispiel.

# %% [markdown]
# ## Datenaufteilung
# 1. Warum wird vor Analyse und Preprocessing gesplittet?
# 2. Welche Aufgaben haben Training, Validation und Test?
# 3. Wann ist stratify wichtig?
# 4. Warum brauchen Patientendaten oft einen Group Split?
# 5. Warum darf eine Zeitreihe normalerweise nicht zufällig gemischt werden?
# 6. Was leistet Cross Validation gegenüber einem einzelnen Split?

# %% [markdown]
# ### Antworten
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.
#
# 6.

# %% [markdown]
# ## Vorverarbeitung
# 7. Was bedeutet Imputation?
# 8. Warum wird Skalierung nur auf Trainingsdaten gelernt?
# 9. Wann ist One-Hot-Encoding sinnvoll, wann Ordinal-Encoding?
# 10. Wie sollte ein Encoder mit einer neuen, unbekannten Kategorie umgehen?
# 11. Nenne ein sinnvolles Feature-Engineering-Beispiel.
# 12. Worin unterscheiden sich Feature Engineering, Feature Extraktion und Feature Selektion?

# %% [markdown]
# ### Antworten
#
# 7.
#
# 8.
#
# 9.
#
# 10.
#
# 11.
#
# 12.

# %% [markdown]
# ## Pipeline und Leakage
# 13. Was ist Data Leakage?
# 14. Wie kann Mittelwert-Imputation Leakage verursachen?
# 15. Was verbindet eine scikit-learn-Pipeline?
# 16. Wofür wird ein ColumnTransformer verwendet?
# 17. Was geschieht bei fit und was bei predict?
# 18. Warum sollte die komplette Pipeline in die Cross Validation gegeben werden?
# 19. Weshalb kann eine sehr hohe Testmetrik verdächtig sein?
# 20. Entwirf für Alter, Einkommen, Stadt und Vertragsart eine passende Vorverarbeitung.

# %% [markdown]
# ### Antworten
#
# 13.
#
# 14.
#
# 15.
#
# 16.
#
# 17.
#
# 18.
#
# 19.
#
# 20.
