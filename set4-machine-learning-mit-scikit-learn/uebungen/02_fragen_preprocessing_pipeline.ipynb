# %% [markdown]
# # Fragen – Datenanalyse, Vorverarbeitung und Pipeline

# %% [markdown]
# ## Daten verstehen
#
# 1. Warum sollte eine Analyse vor jeder automatischen Vorverarbeitung stattfinden?
# 2. Was verraten shape, dtypes und info() jeweils?
# 3. Warum sollte bei value_counts() manchmal dropna=False verwendet werden?
# 4. Was zeigt ein Boxplot und warum darf ein sichtbarer Ausreißer nicht ungeprüft gelöscht werden?
# 5. Worin unterscheiden sich Histogramm, Scatterplot und Balkendiagramm?
# 6. Warum beweist eine hohe Korrelation keine Ursache?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## Vorverarbeitung
#
# 7. Was ist der Unterschied zwischen fit(), transform() und fit_transform()?
# 8. Was lernt SimpleImputer bei strategy="median"?
# 9. Was lernt StandardScaler aus den Daten?
# 10. Warum benötigen kategoriale Texte häufig eine Codierung?
# 11. Was bewirkt handle_unknown="ignore" beim OneHotEncoder?
# 12. Warum darf eine Transformation neuer Daten nicht erneut gefittet werden?

# %% [markdown]
# ### Deine Antworten

# %% [markdown]
# ## Pipeline und ColumnTransformer
#
# 13. Welches Problem löst eine Pipeline?
# 14. Wann ist ein ColumnTransformer sinnvoll?
# 15. Warum müssen Imputation und Skalierung in der richtigen Reihenfolge stehen?
# 16. Welche Vorteile haben benannte Schritte?
# 17. Weshalb sollte eine Vorverarbeitung in einem späteren ML-Projekt nur auf Trainingsdaten gefittet werden?
# 18. Wie könnte die heutige Vorverarbeitung an Tag 5 erweitert werden?

# %% [markdown]
# ### Deine Antworten
