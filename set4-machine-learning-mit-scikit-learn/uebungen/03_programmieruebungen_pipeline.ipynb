# %% [markdown]
# # Programmierübungen – scikit-learn-Pipelines
# Nutze kontrollierte Daten. Halte Testdaten bis zur abschließenden Bewertung unangetastet.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Aufgabe 1 – Nichtlineare Dummy-Daten
# Erzeuge mit make_moons 600 Samples, noise=0.22 und random_state=42. Zeichne beide Klassen in unterschiedlichen Farben. Beschreibe Form, Rauschen und mögliche Ausreißer.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 2 – Sauberer Split
# Teile 75 Prozent Training und 25 Prozent Test mit stratify und random_state=42. Weise nach, dass die Klassenanteile ähnlich bleiben.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 3 – Zwei Pipelines vergleichen
# Baue jeweils StandardScaler plus LogisticRegression sowie StandardScaler plus KNeighborsClassifier. Trainiere nur auf Training und vergleiche Accuracy, Balanced Accuracy und Konfusionsmatrix auf Test.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 4 – Cross Validation
# Vergleiche beide vollständigen Pipelines mit derselben 5-fachen StratifiedKFold-Cross-Validation. Berechne Mittelwert und Standardabweichung der Balanced Accuracy.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 5 – Gemischte Rohdaten
# Erzeuge einen DataFrame mit numerischen Spalten alter und umsatz, Kategorien region und tarif sowie einigen fehlenden Werten. Erzeuge ein binäres Ziel. Splitte zuerst.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 6 – ColumnTransformer
# Numerisch: Median-Imputation und StandardScaler. Kategorial: häufigster Wert und OneHotEncoder mit unbekannten Kategorien. Verbinde alles mit LogisticRegression in einer Pipeline und bewerte auf Test.

# %%
# Dein Code

# %% [markdown]
# ## Aufgabe 7 – Transfer
# Erkläre, welche Split-Strategie du für wiederholte Messungen mehrerer Maschinen und welche für täglich sortierte Verkaufsdaten wählen würdest.

# %% [markdown]
# **Deine Antwort:**
