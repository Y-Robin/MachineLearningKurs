# %% [markdown]
# # Set 02 – Fragenkatalog zu ML-Grundlagen
# Bearbeite die Fragen ohne Programmierung. Formuliere in eigenen Worten; sinnvolle Stichpunkte reichen. **Vorschlag:** 30 Minuten Partnerarbeit, danach gemeinsame Besprechung.

# %% [markdown]
# ## A – Grundbegriffe
# 1. Was ist ein Merkmal beziehungsweise eine Eingabe? Nenne ein Beispiel.
# 2. Was ist ein Label oder Zielwert? Nenne ein Beispiel.
# 3. Was soll ein Modell beim Training lernen?
# 4. Was unterscheidet eine bekannte richtige Antwort von einer Modellvorhersage?
# 5. Warum hängt die Wahl des ML-Verfahrens davon ab, welche Daten vorhanden sind?

# %% [markdown]
# ### Antworten A
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %% [markdown]
# ## B – Lernarten
# 6. Welche Informationen stehen beim überwachten Lernen bereit?
# 7. Welche Information fehlt beim unüberwachten Lernen?
# 8. Was ist die Grundidee des teilüberwachten Lernens?
# 9. Wodurch erhält ein Agent beim Reinforcement Learning Rückmeldung?
# 10. Warum ist Reinforcement Learning nicht einfach eine gewöhnliche Klassifikation?

# %% [markdown]
# ### Antworten B
#
# 6.
#
# 7.
#
# 8.
#
# 9.
#
# 10.

# %% [markdown]
# ## C – Klassifikation und Regression
# 11. Erkläre den Unterschied zwischen Klassifikation und Regression.
# 12. Ordne zu und begründe: Hauspreis, Spam-Erkennung, Energieverbrauch, Tierart auf einem Bild, Defektstatus einer Maschine.
# 13. Kann Diagnoseunterstützung als Klassifikation formuliert werden? Welche besondere Vorsicht ist nötig?

# %% [markdown]
# ### Antworten C
#
# 11.
#
# 12.
#
# 13.

# %% [markdown]
# ## D – Training und Bewertung
# 14. Wozu dient eine Loss-Funktion während des Trainings?
# 15. Was misst Accuracy?
# 16. Warum kann Accuracy bei seltenen, kritischen Fällen irreführend sein?
# 17. Was zeigt eine Konfusionsmatrix zusätzlich?
# 18. Nenne zwei Regressionsmetriken und erkläre sie grob.
# 19. Was unterscheidet Loss-Funktion und Bewertungsmetrik?

# %% [markdown]
# ### Antworten D
#
# 14.
#
# 15.
#
# 16.
#
# 17.
#
# 18.
#
# 19.

# %% [markdown]
# ## E – Strukturen und Anomalien
# 20. Was ist das Ziel von Clustering?
# 21. Wozu kann Dimensionsreduktion dienen? Nenne zwei Zwecke.
# 22. Wie kann Anomalieerkennung mit vielen normalen und wenigen fehlerhaften Beispielen funktionieren?
# 23. Welche Aufgabe hat der Schwellwert?
# 24. Was kann bei einem zu niedrigen oder zu hohen Schwellwert passieren?

# %% [markdown]
# ### Antworten E
#
# 20.
#
# 21.
#
# 22.
#
# 23.
#
# 24.

# %% [markdown]
# ## F – Transfer
# 25. Ein Shop möchte unbekannte Kundentypen entdecken. Welche Lernart und Methode passen?
# 26. Eine Fabrik hat zwei Jahre Normaldaten, aber nur drei Defekte. Welcher Ansatz ist naheliegend?
# 27. Ein Roboter soll durch Ausprobieren greifen lernen. Welche Lernart und welches Feedback passen?
# 28. Warum darf Diagnoseunterstützung Fachpersonal nicht ungeprüft ersetzen?
# 29. Formuliere einen eigenen ML-Fall mit Eingaben, Ergebnis und Lernart.

# %% [markdown]
# ### Antworten F
#
# 25.
#
# 26.
#
# 27.
#
# 28.
#
# 29.

# %% [markdown]
# ## Abschluss
# Markiere drei Fragen, bei denen du noch unsicher bist. Sie werden in der Besprechung zuerst geklärt.
